# %% [markdown]
#   #  Descriptive Statistics
#
#
#   1. Understanding Central Tendency (Easy)
# A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].
# What is the most representative value of their weekly sales, and why?
#      - The most representative value of their weekly sales is 12, because the Mean(Average) is 12.43 which is around 12 so the mean is 12, the Median is also 12 because the middle value of data is 12, the Mode(most frequent value) is also 12, as it appears twice.
#
#
#
#   2. Mean in Real Life (Easy)
# A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
# What is the mean score, and what does it tell us about the class’s performance?
#     - First calculate the sum of scores, 12+15+14+16+18+20+19=114, then count the total number of scores, number of scores(n)= 7, then calculate the mean score by using the mean formula which is [Mean=sum of scores divided by number of scores(n)]= 16.29, the mean scores indicate that the average performance of the class, a mean score is approximately 16.29 out of 20, which shows the students performed well in short quiz.
#
#
#   3.  Mode in Real Life (Easy)
# A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
# What is the mode, and why is this information useful for the store manager?
#      - According to the given data set the mode is 8, because 8 appears three times in the given data set which is more than any other number in the given data set, this information is useful for the store manager because it shows the most popular shoe size sold, it is useful to the manager, manager can use this data(mode) to make sure the store has a sufficient stock of size 8 shoes to fulfill the customers demand.
#
#
#
#   4. Median in Real Life (Medium)
# A car dealer notes the prices of used cars: [$8,000, $9,500, $10,200, $11,000, $50,000].
# Why is the median a better measure than the mean in this case? Calculate the median.
#      - The median is a better measures in this case because the data contains exception, the mean(average) is very much affect by this maximum value, pulling it aside from the typical price range of the majority of the cars, Median is $10200, because it is in the middle of the data, we can also calculate the median position or value by using median formula which is [median position=N+1 divided by 2] = 3rd position which is $10200.
#
#
#   5.  Dispersion Introduction (Medium)
# A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
# What does the range tell us about the variation in the student’s puzzle-solving time?
#       - To find the range, first we have to identify the maximum value and minimum value in the given data set, the maximum is 40 and minimum is 25, the range is the difference between the maximum and minimum value, [Range=Maximum-Minimum] after using the range formula the range is 15, the range of 15 minute means there is a 15 minute difference between longest time take and shortest time taken.
#
#
#
#   6.  Range in Action (Medium)
# A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].
# Find the range. How can this help the farmer in planning his packaging?
#      - To find the range, first we have to identify the maximum value and minimum value in the given data set, the maximum value is 120 and minimum value is 98, the range is the difference between the maximum value and minimum value, [Range=Maximum-Minimum] after using the range formula the range is 22, therefore the the range of the weekly weight of harvested apples is 22kg, the range indicates the variability in the weekly harvest, this helps the farmer in planning his packaging by showing the difference between his best harvest weeks and worst harvest weeks, Plan for packaging needs by making sure enough materials are available to control the maximum amount harvested.
#
#
#
#   7. Variance for Decision-Making (Medium)
# Two delivery companies track delivery delays (in minutes).
# Company A: variance = 6
# Company B: variance = 15
#  Which company is more consistent, and why?
#      - Company A is more consistent because it has lower Variance, Variance is a measure of how extend out a set of data points is from it's mean(average), a lower Variance shows that the data points are grouped  or packed more closely around the average, since there is less variability or change or instability in the delivery delays.
#
#
#
#   8. Standard Deviation in Context (Hard)
# A finance student compares the daily price fluctuations of two cryptocurrencies. Coin A: standard deviation = $30 Coin B: standard deviation = $120 Which coin is riskier to invest in, and why?
#      - Standard deviation is a statistical measure that shows how much the daily prices of an investment vary from the average price, a higher standard deviation means the price fluctuates more significantly indicating higher risk, a lower standard deviation means the price is more stable indicating lower risk, Coin B has a standard deviation of $120, which is much higher coin A whose standard deviation is $30, therefore, Coin B is riskier to invest.
#
#
#
#   9.  Combining Measures (Hard)
# A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410]. Find the mean and standard deviation. What do these values together tell you about the family’s energy use
# pattern?
#       - According to the given data first calculate the mean(average) by using the formula which is [Mean=sum of all observation divided by number of observation(n)] after applying the formula the mean is 414 KWh, then we have to find the squared deviations from the mean: (400-414)²=196, (420-414)²=36, (390-414)²=576, (450-414)²=1296, (410-414)²=16, then we add the squared deviations whose sum is 2120, then we have to calculate the standard deviation by using the formula which is [s=square root (xi-x̌)² divided by (n-1)] , then the result is 23.02 KWh, the mean(414KWh) provides the central or typical monthly energy consumption for this family, the standard deviation which is approx 23.02 KWh is a measure of the data's variability or spread around that mean, relatively low standard deviation compared to the mean indicates that the monthly usage values are tightly grouped around the average, this tells us the family's energy consumption pattern is stable and consistent from month to month, without extreme peaks or troughs, he family's mean electricity usage is 414 kWK and the sample standard deviation is approximately 23.02 kWh  values indicate the family's energy use is relatively consistent and predictable, floating losely around the average, with minimal monthly variation.
#
#
#
#   10.  Practical Application (Hard)
# A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].
# Find the mean, median, mode, range, and standard deviation. What insights can these measures provide
# about the player’s scoring performance?
#        - First calculate the Mean(average) by using the formula which is {mean=sum of all points divided by total number of points}, after applying the formula as result mean is 19.625, then calculate the median the nummber of given data is 8 which is even so there is two middle values which are 19 and 20 and thhe average of two middle values is 18.5, then we calculate the Mode in this data every score appears only once therefore {mode=None(no mode)}, then calculate the range by using range formula which is (Range=Maximum value-Minimum value) after applying the fromula the range is 10, then calculate the squared differences from the mean(19.625): (15 - 19.625)² = 21.390625, (17 - 19.625)² = 6.890625, (18 - 19.625)² = 2.640625, (19 - 19.625)² = 0.390625, (20 - 19.625)² = 0.140625, (21 - 19.625)² = 1.890625, (22 - 19.625)²= 5.640625, (25 -- 19.625)² = 28.890625, then add the squared deviation whose sum is 67.875, now calculate the standard deviation as result the variance is 9.6964, then calculate the square root of variance  then the standard deviation is approximately 3.11 points, these measures suggest that the player has a consistent scoring performance, generally scoring around 22 points per game.
